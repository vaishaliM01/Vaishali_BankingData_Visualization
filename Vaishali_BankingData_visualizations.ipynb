# %%
import pandas as pd

# %%
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
# Out:
# /Users/puneet/anaconda3/lib/python3.11/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/puneet/anaconda3/lib/python3.11/site-packages/visions/backends/shared/nan_handling.py:50: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nb.jit

# %%
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('~/Documents/MSDS_VaishaliWork/MSDS600_DataScience/Week6/Discussion/Banking_TermDeposit.csv')
df
# Out:
#        age           job   marital            education housing loan  \
# 0       49   blue-collar   married             basic.9y      no   no
# 1       37  entrepreneur   married    university.degree      no   no
# 2       78       retired   married             basic.4y      no   no
# 3       36        admin.   married    university.degree     yes   no
# 4       59       retired  divorced    university.degree      no   no
# ...    ...           ...       ...                  ...     ...  ...
# 32945   28      services    single          high.school     yes   no
# 32946   52    technician   married  professional.course     yes   no
# 32947   54        admin.   married             basic.9y      no  yes
# 32948   29        admin.   married    university.degree      no   no
# 32949   35        admin.   married    university.degree      no  yes
#
#          contact     poutcome termdeposit
# 0       cellular  nonexistent          no
# 1      telephone      failure          no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          32950 non-null  int64
#  1   job          32950 non-null  object
#  2   marital      32950 non-null  object
#  3   education    32950 non-null  object
#  4   housing      32950 non-null  object
#  5   loan         32950 non-null  object
#  6   contact      32950 non-null  object
#  7   poutcome     32950 non-null  object
#  8   termdeposit  32950 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.3+ MB

# %% [markdown]
# # Histogram with numeric column age and hue as termdeposit

# %%
sns.histplot(data=df,x=df['age'],hue='termdeposit',bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # Bar Plots for Categorical column "job" with target "termdeposit" as hue

# %%
# Unique values of job
df['job'].unique()
# Out:
# array(['blue-collar', 'entrepreneur', 'retired', 'admin.', 'student',
#        'services', 'technician', 'self-employed', 'management',
#        'unemployed', 'unknown', 'housemaid'], dtype=object)

# %%
fig = plt.figure(figsize=(10, 6)) 
pd.crosstab(df['job'],df['termdeposit']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='job'>

# %% [markdown]
# People with jobs like "admin","blue-collar" and "technician" tend to open more term deposits.

# %% [markdown]
# # Bar Plots for Categorical column "marital" with target "termdeposit" as hue

# %%
fig = plt.figure(figsize=(10, 6)) 
pd.crosstab(df['marital'],df['termdeposit']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='marital'>

# %% [markdown]
# Married people have more term deposits.

# %% [markdown]
# # Based on education

# %%
pd.crosstab(df['education'],df['termdeposit']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='education'>

# %% [markdown]
# University-degree people are opening more TD's whereas illiterates seem to have no TD's

# %% [markdown]
# # Checking based on housing loan

# %%
pd.crosstab(df['housing'],df['termdeposit']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='housing'>

# %% [markdown]
# Housing loan does not look like a major factor to predict term deposits.

# %% [markdown]
# # Plotting boxplot for numeric column age

# %%
sns.boxplot(data=df, orient='h')
# Out:
# <Axes: >

# %% [markdown]
# We observed the people in mid age like 30's and working as admin, blue collar and technicians open more term deposits. Also married people and University-degree people are opening more TD's whereas illiterates seem to have no TD's.
# Housing loan does not look like a major factor to predict term deposits.
# Also tried plotting boxplot for age column.
